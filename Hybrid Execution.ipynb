# %%
! pip install glaredb --upgrade

# %%
import glaredb

# %%
con = glaredb.connect('GLAREDB_CLOUD_CONNECTION_STRING')

# %%
con.sql(
    """
        SELECT * FROM cloud_upload('sales_data.parquet');
    """
       ).to_pandas()
# Out:
#       community_board stump_diam council_district   nta  created_at  \
# 0                 107          0                3  MN14  2015-08-30
# 1                 107          0                3  MN14  2015-08-30
# 2                 104          0                3  MN15  2015-09-07
# 3                 108          0                4  MN40  2015-08-31
# 4                 107          0                6  MN12  2015-09-03
# ...               ...        ...              ...   ...         ...
# 65418             106          0                4  MN19  2015-11-30
# 65419             106          0                4  MN19  2015-11-30
# 65420             105          0                2  MN13  2015-11-19
# 65421             106          0                4  MN19  2015-11-30
# 65422             109          0                7  MN06  2015-11-18
#
#        brch_other         y_sp                                    nta_name  \
# ...
